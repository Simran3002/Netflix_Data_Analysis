# %%
#importing libraries
import pandas as pd
import seaborn as sns
df=pd.read_csv("/content/Netflix_Dataset.csv")

# %%
df
# Out:
#      Show_Id     Type                  Title         Director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    Cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#head fuction shows the first 5 lines of the dataset
df.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#        Releasing_Date  Releasing_Year Rating   Duration  \
# 0  September 25, 2021            2020  PG-13     90 min
# 1  September 24, 2021            2021  TV-MA  2 Seasons
# ...

# %%
#tail function shows the last 5 lines of the dataset 
df.tail()
# Out:
#      Show_Id     Type        Title         Director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    Cast        Country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#          Releasing_Date  Releasing_Year Rating   Duration  \
# 8802  November 20, 2019            2007      R    158 min
# 8803       July 1, 2019            2018  TV-Y7  2 Seasons
# ...

# %%
#shape is used to show the number of rows and columns
df.shape
# Out:
# (8807, 12)

# %%
#It is used to show the total number of elements in the dataset
df.size
# Out:
# 105684

# %%
#shows the name of the columns  
df.columns
# Out:
# Index(['Show_Id', 'Type', 'Title', 'Director', 'Cast', 'Country',
#        'Releasing_Date', 'Releasing_Year', 'Rating', 'Duration', 'Listed_In',
#        'Description'],
#       dtype='object')

# %%
#show the datatype of the column
df.dtypes
# Out:
# Show_Id           object
# Type              object
# Title             object
# Director          object
# Cast              object
# Country           object
# Releasing_Date    object
# Releasing_Year     int64
# Rating            object
# Duration          object
# Listed_In         object
# Description       object
# dtype: object

# %%
#shows the index,column,datatype ofeach column and memory at once.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Show_Id         8807 non-null   object
#  1   Type            8807 non-null   object
#  2   Title           8807 non-null   object
#  3   Director        6173 non-null   object
#  4   Cast            7982 non-null   object
#  5   Country         7976 non-null   object
#  6   Releasing_Date  8797 non-null   object
#  7   Releasing_Year  8807 non-null   int64
#  8   Rating          8803 non-null   object
#  9   Duration        8804 non-null   object
#  10  Listed_In       8807 non-null   object
#  11  Description     8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# **1) Is there any Duplicate Record in the dataset? If present then remove it.**

# %%
#find duplicate record
df[df.duplicated()]

#below output shows that there is no duplicate record is present in the dataset.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Type, Title, Director, Cast, Country, Releasing_Date, Releasing_Year, Rating, Duration, Listed_In, Description]
# Index: []

# %% [markdown]
#  **2) Is there any Null values present in the column?Show with Heat Map.**

# %%
#shows the null value is present or not
df.isnull()

#below output is shown in the form of boolean value
#True means null values are present and False means null values are not present
# Out:
#       Show_Id   Type  Title  Director   Cast  Country  Releasing_Date  \
# 0       False  False  False     False   True    False           False
# 1       False  False  False      True  False    False           False
# 2       False  False  False     False  False     True           False
# 3       False  False  False      True   True     True           False
# 4       False  False  False      True  False    False           False
# ...       ...    ...    ...       ...    ...      ...             ...
# 8802    False  False  False     False  False    False           False
# 8803    False  False  False      True   True     True           False
# 8804    False  False  False     False  False    False           False
# 8805    False  False  False     False  False    False           False
# 8806    False  False  False     False  False    False           False
#
#       Releasing_Year  Rating  Duration  Listed_In  Description
# 0              False   False     False      False        False
# ...

# %%
#shows the count of null values in each column
df.isnull().sum()
# Out:
# Show_Id              0
# Type                 0
# Title                0
# Director          2634
# Cast               825
# Country            831
# Releasing_Date      10
# Releasing_Year       0
# Rating               4
# Duration             3
# Listed_In            0
# Description          0
# dtype: int64

# %%
#Now we show the null values with the heat map
sns.heatmap(df.isnull())

#In below heat map null values shows in white colour

# %%
#removing null values
df.dropna().head()
# Out:
#    Show_Id     Type                          Title             Director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  Cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               Country      Releasing_Date  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
df.isnull()
# Out:
#       Show_Id   Type  Title  Director   Cast  Country  Releasing_Date  \
# 0       False  False  False     False   True    False           False
# 1       False  False  False      True  False    False           False
# 2       False  False  False     False  False     True           False
# 3       False  False  False      True   True     True           False
# 4       False  False  False      True  False    False           False
# ...       ...    ...    ...       ...    ...      ...             ...
# 8802    False  False  False     False  False    False           False
# 8803    False  False  False      True   True     True           False
# 8804    False  False  False     False  False    False           False
# 8805    False  False  False     False  False    False           False
# 8806    False  False  False     False  False    False           False
#
#       Releasing_Year  Rating  Duration  Listed_In  Description
# 0              False   False     False      False        False
# ...

# %% [markdown]
# **3) For 'House of Cards', What is the Show Id and Who is the Director of this Show?**

# %%
#Show all the records of a particular item in any column
df.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#        Releasing_Date  Releasing_Year Rating   Duration  \
# 0  September 25, 2021            2020  PG-13     90 min
# 1  September 24, 2021            2021  TV-MA  2 Seasons
# ...

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id     Type           Title Director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    Cast        Country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#       Releasing_Date  Releasing_Year Rating   Duration  \
# 1059  April 14, 2021            2018  TV-MA  6 Seasons
#
#                     Listed_In  \
# 1059  TV Dramas, TV Thrillers
#
#                                             Description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# **5) In which year highest number of the TV Shows & Movies were released? Show with Bar Graph. **

# %%
#check the datatype of column
df.dtypes
# Out:
# Show_Id           object
# Type              object
# Title             object
# Director          object
# Cast              object
# Country           object
# Releasing_Date    object
# Releasing_Year     int64
# Rating            object
# Duration          object
# Listed_In         object
# Description       object
# dtype: object

# %%
#now change the datatype of coulmn
df['Date'] = pd.to_datetime(df['Releasing_Date'])

#see the new column is added in the dataset
df.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#        Releasing_Date  Releasing_Year Rating   Duration  \
# 0  September 25, 2021            2020  PG-13     90 min
# 1  September 24, 2021            2021  TV-MA  2 Seasons
# ...

# %%
#also check the datatype of new column
df.dtypes
# Out:
# Show_Id                   object
# Type                      object
# Title                     object
# Director                  object
# Cast                      object
# Country                   object
# Releasing_Date            object
# Releasing_Year             int64
# Rating                    object
# Duration                  object
# Listed_In                 object
# Description               object
# Date              datetime64[ns]
# dtype: object

# %%
#count values of TV Shows and movies were released
df['Date'].dt.year.value_counts()

#shows year wise result
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date, dtype: int64

# %%
#Now show it with bar graph
df['Date'].dt.year.value_counts().plot(kind='bar')

# %% [markdown]
# **6) How many Movies & TV Shows are in the dataset? Show with Bar Graph**

# %%
#show all unique items of column and their count
df.groupby('Type').Type.count()
# Out:
# Type
# Movie      6131
# TV Show    2676
# Name: Type, dtype: int64

# %%
#Show it with graph
sns.countplot(df['Type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **7) Show only TV Shows that are released in India.**

# %%
df[ (df['Type']=='TV Show') & (df['Country']=='India') ]
# Out:
#      Show_Id     Type                               Title Director  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    Cast Country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %% [markdown]
# **7)Show Top 10 Directors, who gave highest number of TV Shows & Movies to Netflix? Show with Histogram**

# %%
#Top 10 directors who give highest no. of TV Show to Netflix
df['Director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: Director, dtype: int64

# %%
sns.histplot(df['Director'].value_counts().head(10))

# %% [markdown]
# **8) Show all the records where "Type is Movie and Type is Comedies" or "Country is United Kingdom".**

# %%
df[ (df['Type']=='Movie') & (df['Listed_In']=='Comedies') | (df['Country'] =='United Kingdom')]
# Out:
#      Show_Id     Type                                   Title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              Director                                               Cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# **9)What are the different Rating defined by Netflix**

# %%
#shows rating of data
df['Rating'].nunique()
# Out:
# 17

# %%
df['Rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# **10)  What is the Maximum duration of a Movie on Netflix?**

# %%
#shows duration
df.Duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df.Duration.dtypes
#here o means this is object datatype
# Out:
# dtype('O')

# %%
#now we have to change the datatype
#split out the elements
df[['Minutes','Unit']] = df['Duration'].str.split(' ', expand= True)

# %%
df.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#        Releasing_Date  Releasing_Year Rating   Duration  \
# 0  September 25, 2021            2020  PG-13     90 min
# 1  September 24, 2021            2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# **11)How can we sort the dataset of year?**

# %%
#Sort the values of year
df.sort_values(by='Releasing_Year')
# Out:
#      Show_Id     Type                                          Title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          Director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
#if you want the latest year i.e decreasing order
#with top ten records
df.sort_values(by='Releasing_Year',ascending=False)
# Out:
#      Show_Id     Type                                          Title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             Director                                               Cast  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a92655c80d73> in <module>()
# ----> 1 sns.pairplot("Netflix_Dataset.csv")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2079         raise TypeError(
#    2080             "'data' must be pandas DataFrame object, not: {typefound}".format(
# -> 2081                 typefound=type(data)))
#    2082
#    2083     plot_kws = {} if plot_kws is None else plot_kws.copy()
# ...
